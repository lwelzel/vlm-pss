# %%
# %load_ext autoreload
# %autoreload 2

# %%
from PSS_design import optimize_pss_mipego, design_from_para

# %%
# run mipego
xopt, fopt, stop_dict = optimize_pss_mipego(adaptive_fn_eval=2500, warm_up_fn_eval=5000, n_per_iter=50,
                                            n_cores=25, f_name="MIPEGO_results_full2.csv")

print('xopt: {}'.format(xopt))
print('fopt: {}'.format(fopt))
print('stop criteria: {}'.format(stop_dict))
# Out:
# 12/09/2022 18:17:50,139 - [AnnealingBO.INFO] -- evaluation takes 9.4337s
# 12/09/2022 18:17:50,142 - [AnnealingBO.INFO] -- initial DoE of size 5000:
# 12/09/2022 18:17:50,144 - [AnnealingBO.INFO] -- #1 - fitness: 491.73113923059657, solution: [3, 2, 23, 0.0089821, 0.0044949000000000005, 0.03482575, -0.017414, 0.016797500000000003]
# 12/09/2022 18:17:50,144 - [AnnealingBO.INFO] -- #2 - fitness: 2560.4160257664375, solution: [0, 1, 21, 0.0094699, 0.00142554, 0.06926425000000001, -0.008226, 0.021567500000000003]
# 12/09/2022 18:17:50,144 - [AnnealingBO.INFO] -- #3 - fitness: -1.7169035575701292, solution: [2, 0, 8, 0.0085393, 0.00317598, 0.011133250000000003, -0.005873999999999999, 0.004532500000000001]
# 12/09/2022 18:17:50,145 - [AnnealingBO.INFO] -- #4 - fitness: 1760.198342314276, solution: [0, 3, 47, 0.0066313000000000006, 0.00114482, 0.05674975000000001, -0.01983, 0.020777500000000004]
# ...

# %%
buffer_xopt, buffer_fopt, buffer_stop_dict = xopt, fopt, stop_dict
